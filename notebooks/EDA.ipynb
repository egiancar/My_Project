# %%
import pandas as pd
import plotly.express as px

# Cargar el dataset
car_data = pd.read_csv('../vehicles_us.csv') 

# Vista rápida de los datos
car_data.head()
# Out:
#    price  model_year           model  condition  cylinders fuel  odometer  \
# 0   9400      2011.0          bmw x5       good        6.0  gas  145000.0
# 1  25500         NaN      ford f-150       good        6.0  gas   88705.0
# 2   5500      2013.0  hyundai sonata   like new        4.0  gas  110000.0
# 3   1500      2003.0      ford f-150       fair        8.0  gas       NaN
# 4  14900      2017.0    chrysler 200  excellent        4.0  gas   80903.0
#
#   transmission    type paint_color  is_4wd date_posted  days_listed
# 0    automatic     SUV         NaN     1.0  2018-06-23           19
# 1    automatic  pickup       white     1.0  2018-10-19           50
# 2    automatic   sedan         red     NaN  2019-02-07           79
# 3    automatic  pickup         NaN     NaN  2019-03-22            9
# 4    automatic   sedan       black     NaN  2019-04-02           28

# %%
# %pip install "nbformat>=4.2.0"

fig = px.histogram(car_data, x="odometer")
fig.show()
# Out:
# Collecting nbformat>=4.2.0
#   Downloading nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
# Collecting fastjsonschema>=2.15 (from nbformat>=4.2.0)
#   Downloading fastjsonschema-2.21.2-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: jsonschema>=2.6 in /opt/miniconda3/envs/MiEspacio/lib/python3.13/site-packages (from nbformat>=4.2.0) (4.26.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/miniconda3/envs/MiEspacio/lib/python3.13/site-packages (from nbformat>=4.2.0) (5.9.1)
# Requirement already satisfied: traitlets>=5.1 in /opt/miniconda3/envs/MiEspacio/lib/python3.13/site-packages (from nbformat>=4.2.0) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in /opt/miniconda3/envs/MiEspacio/lib/python3.13/site-packages (from jsonschema>=2.6->nbformat>=4.2.0) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/miniconda3/envs/MiEspacio/lib/python3.13/site-packages (from jsonschema>=2.6->nbformat>=4.2.0) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/miniconda3/envs/MiEspacio/lib/python3.13/site-packages (from jsonschema>=2.6->nbformat>=4.2.0) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /opt/miniconda3/envs/MiEspacio/lib/python3.13/site-packages (from jsonschema>=2.6->nbformat>=4.2.0) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/miniconda3/envs/MiEspacio/lib/python3.13/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0) (4.5.1)
# Downloading nbformat-5.10.4-py3-none-any.whl (78 kB)
# Downloading fastjsonschema-2.21.2-py3-none-any.whl (24 kB)
# Installing collected packages: fastjsonschema, nbformat
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [nbformat]1/2 [nbformat]
# Successfully installed fastjsonschema-2.21.2 nbformat-5.10.4
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 4
#       1 get_ipython().run_line_magic('pip', 'install "nbformat>=4.2.0"')
#       3 fig = px.histogram(car_data, x="odometer")
# ----> 4 fig.show()
#
# File /opt/miniconda3/envs/MiEspacio/lib/python3.13/site-packages/plotly/basedatatypes.py:3420, in BaseFigure.show(self, *args, **kwargs)
#    3387 """
#    3388 Show a figure using either the default renderer(s) or the renderer(s)
#    3389 specified by the renderer argument
#    (...)   3416 None
#    3417 """
#    3418 import plotly.io as pio
# -> 3420 return pio.show(self, *args, **kwargs)
#
# File /opt/miniconda3/envs/MiEspacio/lib/python3.13/site-packages/plotly/io/_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
#     412     )
#     414 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 415     raise ValueError(
#     416         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     417     )
#     419 display_jupyter_version_warnings()
#     421 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
